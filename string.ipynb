# %% [markdown]
# <a href="https://colab.research.google.com/github/vikxram/Data-Science/blob/main/string.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Strings
#
# in python specifically , strings are a sequence of Unicode characters

# %%
# indexing

s = "hello google"
print(s[9])
# Out:
# g

# %%
# slicing
s = "hello google"
# for i in range (3,9):
#   print(s[i],end = "")

print(s[2:5])
# Out:
# llo

# %%
# EDITING  IN STRING ID NOT ALLOW SO IT'S A IMMUTABLE


s ='hello'
s[1] = 'L'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_252/2564261606.py in <cell line: 0>()
#       3
#       4 s ='hello'
# ----> 5 s[1] = 'L'
#
# TypeError: 'str' object does not support item assignment

# %% [markdown]
# # common function
#   * len
#   * max
#   * min
#   * sorted

# %%
len("hello world")
# Out:
# 11

# %%
max("hello worldz")
# Out:
# 'z'

# %%
min("helloworld")
# Out:
# 'd'

# %%
sorted("vikram shah")
# Out:
# [' ', 'a', 'a', 'h', 'h', 'i', 'k', 'm', 'r', 's', 'v']

# %%
sorted("vikram shah",  reverse=True)
# Out:
# ['v', 's', 'r', 'm', 'k', 'i', 'h', 'h', 'a', 'a', ' ']

# %%
# capitlize

s = "vikxramm"
s.capitalize()
# Out:
# 'Vikxramm'

# %%
# title
s = "vikxramm shah"
s.title()
# Out:
# 'Vikxramm Shah'

# %%
# upper
s = "vikxramm shah"
s.upper()
# Out:
# 'VIKXRAMM SHAH'

# %%
#lower
s = "VIKRAM SHAHaaa"
s.lower()
# Out:
# 'vikram shahaaa'

# %%
# swape case
s = "VIkram SHah"
s.swapcase()
# Out:
# 'viKRAM shAH'

# %%
# Count
'my name is vikram shah'.count('a')
# Out:
# 3

# %%
# Find

'my name is vikram shah'.find('x')
# Out:
# -1

# %%
# Index

'my name is vikram shah'.index('a')
# Out:
# 4

# %% [markdown]
# # isalnum / isalpha / isdigit/ isidentifier

# %%
# isalnum

'vikram1234'.isalnum()
# Out:
# True

# %%
'vikram1234%'.isalnum()
# Out:
# False

# %%
#isalpha
'vikram'.isalpha()
# Out:
# True

# %%
#isdigit
'22346543'.isdigit()
# Out:
# True

# %%
#identifier
'name'.isidentifier()
# Out:
# True

# %% [markdown]
# # split / join / replace / strip

# %%
# split
'hi my name is vikram'.split()
# Out:
# ['hi', 'my', 'name', 'is', 'vikram']

# %%
# join
"-".join(['hi', 'my', 'name', 'is', 'vikram'])
# Out:
# 'hi-my-name-is-vikram'

# %%
#replace
'hi my name is vikram'.replace('vikram','jack')
# Out:
# 'hi my name is jack'

# %%
#strip
'vikram    '.strip()
# Out:
# 'vikram'

# %% [markdown]
# # Example problams

# %%
# fin the len of a given string without using the len() function

s = input("enter the string")
counter = 0
for i in s:
  counter += 1
print(counter)
# Out:
# enter the stringvikramshah
# 10

# %%
# extract username form a given string
s = input("enter the email ")
pos = s.index('@')
print(s[0:pos])
# Out:
# enter the email vikramm1410@gmail.com
# vikramm1410

# %%
# is palindrome or not
s = input("enter the string  ")
flag = True
for i in range (0,len(s)//2):
  if s[i] != s[len(s)-i-1]:
    flag = False
    break
if flag:
  print("palindrome")
# Out:
# enter the string  wertrew
# palindrome
